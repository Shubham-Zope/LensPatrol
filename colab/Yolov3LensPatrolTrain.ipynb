# %%
# !nvidia-smi
# Out:
# Tue Oct 25 13:40:54 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   51C    P8    10W /  70W |      0MiB / 15109MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# !ln -s /content/gdrive/My\ Drive/ /mydrive
# !ls /mydrive
# Out:
# Mounted at /content/gdrive
#  20211230_075600.jpg
#  20211230_075601.jpg
#  20211230_075602.jpg
#  20211230_075645.jpg
#  20211230_075651.jpg
#  20211230_075726.jpg
#  20211230_075728.jpg
#  20211230_075729.jpg
#  Agreement.pdf
# 'Aoa notes.gdoc'
# 'aoa viva (1).gdoc'
# 'aoa viva.gdoc'
# 'Aptitude- Puzzles.gdoc'
# 'areafill (1).c.gdoc'
# 'areafill (2).c.gdoc'
# 'areafill (3).c.gdoc'
# 'areafill (4).c.gdoc'
# 'areafill (5).c.gdoc'
# 'areafill (6).c.gdoc'
#  areafill.c.gdoc
# 'Bubble and Insertion.rtf.gdoc'
#  c4_200m_550k.csv
# 'CG_Front Page.gdoc'
# 'CG practical 3.docx'
#  CNviva.gdoc
# 'Colab Notebooks'
#  Combined_images_yolo
# 'computer graphics Pdf.pdf'
#  Conf.zip
# 'Copy of contacts.gsheet'
# 'Copy of water level indicator project -converted - 13 November, 20:30.gdoc'
#  data.csv
# 'dbms_asgn1 (1).gdoc'
# 'dbms_asgn1 (2).gdoc'
# 'dbms_asgn1 (3).gdoc'
# 'dbms_asgn1 (4).gdoc'
# 'dbms_asgn1 (5).gdoc'
# 'dbms_asgn1 (6).gdoc'
#  dbms_asgn1.gdoc
#  Details.gdoc
# ...

# %%
# !git clone https://github.com/AlexeyAB/darknet
# Out:
# Cloning into 'darknet'...
# remote: Enumerating objects: 15494, done.
# remote: Counting objects: 100% (4/4), done.
# remote: Compressing objects: 100% (4/4), done.
# remote: Total 15494 (delta 0), reused 1 (delta 0), pack-reused 15490
# Receiving objects: 100% (15494/15494), 14.09 MiB | 25.30 MiB/s, done.
# Resolving deltas: 100% (10411/10411), done.

# %%
# %cd darknet
# !sed -i 's/OPENCV=0/OPENCV=1/' Makefile
# !sed -i 's/GPU=0/GPU=1/' Makefile
# !sed -i 's/CUDNN=0/CUDNN=1/' Makefile
# !make
# Out:
# /content/darknet
# mkdir -p ./obj/
# mkdir -p backup
# chmod +x *.sh
# g++ -std=c++11 -std=c++11 -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/image_opencv.cpp -o obj/image_opencv.o
# ./src/image_opencv.cpp: In function ‘void draw_detections_cv_v3(void**, detection*, int, float, char**, image**, int, int)’:
# ./src/image_opencv.cpp:946:23: warning: variable ‘rgb’ set but not used [-Wunused-but-set-variable]
#                  float rgb[3];
#                        ^~~
# ./src/image_opencv.cpp: In function ‘void draw_train_loss(char*, void**, int, float, float, int, int, float, int, char*, float, int, int, double)’:
# ./src/image_opencv.cpp:1147:13: warning: this ‘if’ clause does not guard... [-Wmisleading-indentation]
# ...

# %%
# !cp cfg/yolov3.cfg cfg/yolov3_training.cfg

# %%
# !sed -i 's/batch=1/batch=64/' cfg/yolov3_training.cfg
# !sed -i 's/subdivisions=1/subdivisions=16/' cfg/yolov3_training.cfg
# !sed -i 's/max_batches = 500200/max_batches = 8000/' cfg/yolov3_training.cfg
# !sed -i '610 s@classes=80@classes=4@' cfg/yolov3_training.cfg
# !sed -i '696 s@classes=80@classes=4@' cfg/yolov3_training.cfg
# !sed -i '783 s@classes=80@classes=4@' cfg/yolov3_training.cfg
# !sed -i '603 s@filters=255@filters=27@' cfg/yolov3_training.cfg
# !sed -i '689 s@filters=255@filters=27@' cfg/yolov3_training.cfg
# !sed -i '776 s@filters=255@filters=27@' cfg/yolov3_training.cfg

# %%
# !mkdir "/mydrive/Combined_images_yolo"
# Out:
# mkdir: cannot create directory ‘/mydrive/Combined_images_yolo’: File exists

# %%
# !echo -e 'snatch\nweapon\nmask\nfire' > data/obj.names
# !echo -e 'classes= 4\ntrain  = data/train.txt\nvalid  = data/test.txt\nnames = data/obj.names\nbackup = /mydrive/Combined_images_yolo' > data/obj.data
# !mkdir data/obj

# %%
# !wget https://pjreddie.com/media/files/darknet53.conv.74
# Out:
# --2022-10-25 13:45:29--  https://pjreddie.com/media/files/darknet53.conv.74
# Resolving pjreddie.com (pjreddie.com)... 128.208.4.108
# Connecting to pjreddie.com (pjreddie.com)|128.208.4.108|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 162482580 (155M) [application/octet-stream]
# Saving to: ‘darknet53.conv.74’
#
# darknet53.conv.74   100%[===================>] 154.96M  45.5MB/s    in 3.7s
#
# 2022-10-25 13:45:33 (41.5 MB/s) - ‘darknet53.conv.74’ saved [162482580/162482580]

# %%
# !unzip  /mydrive/Combined_images_yolo/combined_images.zip -d data/obj
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: data/obj/theft1674.jpg
#  extracting: data/obj/theft1674.txt
#   inflating: data/obj/theft1677.jpg
#   inflating: data/obj/theft1677.txt
#   inflating: data/obj/theft169.jpg
#  extracting: data/obj/theft169.txt
#   inflating: data/obj/theft17.jpg
#  extracting: data/obj/theft17.txt
#   inflating: data/obj/theft1717.jpg
#  extracting: data/obj/theft1717.txt
#   inflating: data/obj/theft1744.jpg
#  extracting: data/obj/theft1744.txt
#   inflating: data/obj/theft1746.jpg
#   inflating: data/obj/theft1746.txt
#   inflating: data/obj/theft1747.jpg
#   inflating: data/obj/theft1747.txt
#   inflating: data/obj/theft175.jpg
#  extracting: data/obj/theft175.txt
#   inflating: data/obj/theft1763.jpg
#  extracting: data/obj/theft1763.txt
#   inflating: data/obj/theft1765.jpg
#   inflating: data/obj/theft1765.txt
#   inflating: data/obj/theft1766.jpg
#  extracting: data/obj/theft1766.txt
#   inflating: data/obj/theft1767.jpg
# ...

# %%
import os
print(len(os.listdir('data/obj')))
# Out:
# 16109

# %%
import glob
images_list_jpg = glob.glob("data/obj/*.jpg")
print(images_list_jpg)
print(len(images_list_jpg))
# Out:
# ['data/obj/98.jpg', 'data/obj/mask3439.jpg', 'data/obj/00000152.jpg', 'data/obj/mask1668.jpg', 'data/obj/FireDetectionImage_MirrorWEBFire088.jpg', 'data/obj/weapon6302.jpg', 'data/obj/301.jpg', 'data/obj/CA02110.jpg', 'data/obj/mask5237.jpg', 'data/obj/weapon2175.jpg', 'data/obj/CA04004.jpg', 'data/obj/WEBSmoke1628.jpg', 'data/obj/mask5638.jpg', 'data/obj/58.69222639.jpg', 'data/obj/MirrorWEBFire409.jpg', 'data/obj/weapon47.jpg', 'data/obj/939.jpg', 'data/obj/CAR00089.jpg', 'data/obj/MirrorWEBFire2137.jpg', 'data/obj/WEBSmoke549.jpg', 'data/obj/weapon5180.jpg', 'data/obj/mask5561.jpg', 'data/obj/mask5117.jpg', 'data/obj/mask3036.jpg', 'data/obj/WEBFire1100.jpg', 'data/obj/f6ec33a7cb69a4fc.jpg', 'data/obj/new_fire_23.jpg', 'data/obj/NoiseWEBFire187.jpg', 'data/obj/NoiseWEBFire1090.jpg', 'data/obj/WEBFire1394.jpg', 'data/obj/mask3447.jpg', 'data/obj/Copy of 4.jpg', 'data/obj/weapon1714.jpg', 'data/obj/mask6481.jpg', 'data/obj/WEBFire568.jpg', 'data/obj/NoiseWEBFire1358.jpg', 'data/obj/
# ...

# %%
import glob
images_list_png = glob.glob("data/obj/*.png")
print(images_list_png)
print(len(images_list_png))
# Out:
# ['data/obj/new_fire_fire.193.png', 'data/obj/new_fire_fire.44.png', 'data/obj/new_fire_fire.585.png', 'data/obj/new_fire_fire.626.png', 'data/obj/new_fire_fire.258.png', 'data/obj/new_fire_fire.701.png', 'data/obj/new_fire_fire.684.png', 'data/obj/new_fire_fire.447.png', 'data/obj/new_fire_fire.395.png', 'data/obj/new_fire_fire.445.png', 'data/obj/new_fire_fire.599.png', 'data/obj/new_fire_fire.212.png', 'data/obj/new_fire_fire.66.png', 'data/obj/new_fire_fire.128.png', 'data/obj/new_fire_fire.311.png', 'data/obj/new_fire_fire.600.png', 'data/obj/new_fire_fire.186.png', 'data/obj/new_fire_fire.188.png', 'data/obj/new_fire_fire.91.png', 'data/obj/new_fire_fire.387.png', 'data/obj/new_fire_fire.43.png', 'data/obj/new_fire_fire.433.png', 'data/obj/new_fire_fire.430.png', 'data/obj/new_fire_fire.126.png', 'data/obj/new_fire_fire.640.png', 'data/obj/new_fire_fire.146.png', 'data/obj/new_fire_fire.247.png', 'data/obj/new_fire_fire.122.png', 'data/obj/new_fire_fire.579.png', 'data/obj/new_f
# ...

# %%
image_list = images_list_jpg + images_list_png
print(image_list)
print(len(image_list))
# Out:
# ['data/obj/98.jpg', 'data/obj/mask3439.jpg', 'data/obj/00000152.jpg', 'data/obj/mask1668.jpg', 'data/obj/FireDetectionImage_MirrorWEBFire088.jpg', 'data/obj/weapon6302.jpg', 'data/obj/301.jpg', 'data/obj/CA02110.jpg', 'data/obj/mask5237.jpg', 'data/obj/weapon2175.jpg', 'data/obj/CA04004.jpg', 'data/obj/WEBSmoke1628.jpg', 'data/obj/mask5638.jpg', 'data/obj/58.69222639.jpg', 'data/obj/MirrorWEBFire409.jpg', 'data/obj/weapon47.jpg', 'data/obj/939.jpg', 'data/obj/CAR00089.jpg', 'data/obj/MirrorWEBFire2137.jpg', 'data/obj/WEBSmoke549.jpg', 'data/obj/weapon5180.jpg', 'data/obj/mask5561.jpg', 'data/obj/mask5117.jpg', 'data/obj/mask3036.jpg', 'data/obj/WEBFire1100.jpg', 'data/obj/f6ec33a7cb69a4fc.jpg', 'data/obj/new_fire_23.jpg', 'data/obj/NoiseWEBFire187.jpg', 'data/obj/NoiseWEBFire1090.jpg', 'data/obj/WEBFire1394.jpg', 'data/obj/mask3447.jpg', 'data/obj/Copy of 4.jpg', 'data/obj/weapon1714.jpg', 'data/obj/mask6481.jpg', 'data/obj/WEBFire568.jpg', 'data/obj/NoiseWEBFire1358.jpg', 'data/obj/
# ...

# %%
file = open("data/train.txt", "w") 
file.write("\n".join(image_list)) 
file.close()

# %%
# !./darknet detector train data/obj.data cfg/yolov3_training.cfg darknet53.conv.74 -dont_show
# Out:
# /bin/bash: ./darknet: No such file or directory

# %%
# !./darknet detector train data/obj.data cfg/yolov3_training.cfg /content/gdrive/MyDrive/Combined_images_yolo/yolov3_training_last.weights -dont_show
# Out:
# Streaming output truncated to the last 5000 lines.
#  total_bbox = 123790, rewritten_bbox = 0.017772 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.768201), count: 5, class_loss = 1.164758, iou_loss = 0.293269, total_loss = 1.458027
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 1, class_loss = 0.163562, iou_loss = 0.000000, total_loss = 0.163562
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.347911), count: 2, class_loss = 0.223429, iou_loss = 0.545626, total_loss = 0.769054
#  total_bbox = 123797, rewritten_bbox = 0.017771 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.778703), count: 2, class_loss = 0.199625, iou_loss = 0.077687, total_loss = 0.277311
# ...
